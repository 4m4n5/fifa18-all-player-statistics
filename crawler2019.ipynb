# %%
# Initial imports
import numpy as np
import pandas as pd 
from pandas import DataFrame, Series
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
# %matplotlib inline

import random
import re
import urllib.request
import requests
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings('ignore')
pd.set_option('display.max_columns', 500)

# %%
base_url = "https://sofifa.com/players?offset="
columns = ['ID', 'Name', 'Age', 'Photo', 'Nationality', 'Flag', 'Overall', 'Potential', 'Club', 
           'Club Logo', 'Value', 'Wage', 'Special']
data = DataFrame(columns=columns)
for offset in range(225):
    url = base_url + str(offset*60)
    source_code = requests.get(url)
    plain_text = source_code.text
    soup = BeautifulSoup(plain_text)
    table_body = soup.find('tbody')
    for row in table_body.findAll('tr'):
        td = row.findAll('td')
        picture = td[0].find('img').get('data-src')
        pid = td[0].find('img').get('id')
        nationality = td[1].find('a').get('title')
        flag_img = td[1].find('img').get('data-src')
        name = td[1].findAll('a')[1].text
        age = td[2].find('div').text.strip()
        overall = td[3].text.strip()
        potential = td[4].text.strip()
        club = td[5].find('a').text
        club_logo = td[5].find('img').get('data-src')
        value = td[6].text.strip()
        wage = td[7].text.strip()
        special = td[8].text.strip()
        player_data = DataFrame([[pid, name, age, picture, nationality, flag_img, overall, potential, club, club_logo, value, wage, special]])
        player_data.columns = columns
        data = data.append(player_data, ignore_index=True)
    offset+=1

# %%
master_data = DataFrame()
r = 0
player_data_url = 'https://sofifa.com/player/'
for index, row in data.iterrows():
    skill_names = []
    skill_map = {'ID' : str(row['ID'])}
    url = player_data_url + str(row['ID'])
    source_code = requests.get(url)
    plain_text = source_code.text
    soup = BeautifulSoup(plain_text)
    categories = soup.find('div', {'class': 'teams'}).findAll('div', {'class': 'column col-4'})[0:3]
    for category in categories:
        skills = category.findAll('li')
        for skill in skills:
            if(skill.find('label') != None):
                a = skill.text
                n = skill.find('label').text
                value = a.replace(n, '').strip()
                skill_names.append(n)
                skill_map[str(n)] = value
    if(soup.find('aside').find('div', {'class': 'card mb-2'}).find('div', {'class': 'card-body'})):
        card_rows = soup.find('aside').find('div', {'class': 'card mb-2'}).find('div', {'class': 'card-body'}).findAll('div', {'class': 'columns'})
        for row in card_rows:
            attributes = row.findAll('div', {'class': re.compile('column col-sm-2 text-center')})
            for attribute in attributes:
                if(attribute.find('div')):
                    text = attribute.text
                    name = ''.join(re.findall('[a-zA-Z]', text))
                    value = text.replace(name, '').strip()
                    skill_names.append(name)
                    skill_map[str(name)] = value
    else:
        for name in master_data.columns[12:38]:
            skill_names.append(name)
            skill_map[str(name)] = None
    attr_data = DataFrame(columns=skill_names)
    for key in skill_map.keys():
        attr_data.loc[r,key] = skill_map[key]
    r = r + 1
    print(skill_map['ID'])
    print(attr_data.shape)
    print(attr_data.columns)
    master_data = master_data.append([attr_data])
# Out:
# 158023
# (1, 39)
# Index(['Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Release Clause',
#        'Position', 'Jersey Number', 'Joined', 'Contract Valid Until', 'LS',
#        'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM',
#        'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
#        'LCB', 'CB', 'RCB', 'RB', 'ID'],
#       dtype='object')
# 20801
# (1, 39)
# Index(['Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Release Clause',
#        'Position', 'Jersey Number', 'Joined', 'Contract Valid Until', 'LS',
#        'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM',
#        'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
#        'LCB', 'CB', 'RCB', 'RB', 'ID'],
#       dtype='object')
# 190871
# (1, 39)
# Index(['Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Release Clause',
#        'Position', 'Jersey Number', 'Joined', 'Contract Valid Until', 'LS',
#        'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM',
#        'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
#        'LCB', 'CB', 'RCB', 'RB', 'ID'],
#       dtype='object')
# 193080
# (1, 39)
# Index(['Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Release Clause',
#        'Position', 'Jersey Number', 'Joined', 'Contract Valid Until', 'LS',
#        'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM',
#        'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
#        'LCB', 'CB', 'RCB', 'RB', 'ID'],
#       dtype='object')
# 192985
# (1, 39)
# Index(['Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Release Clause',
#        'Position', 'Jersey Number', 'Joined', 'Contract Valid Until', 'LS',
#        'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM',
#        'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
#        'LCB', 'CB', 'RCB', 'RB', 'ID'],
#       dtype='object')
# 183277
# (1, 39)
# Index(['Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Release Clause',
#        'Position', 'Jersey Number', 'Joined', 'Contract Valid Until', 'LS',
#        'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM',
#        'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
#        'LCB', 'CB', 'RCB', 'RB', 'ID'],
#       dtype='object')
# 177003
# (1, 39)
# Index(['Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Release Clause',
#        'Position', 'Jersey Number', 'Joined', 'Contract Valid Until', 'LS',
#        'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM',
#        'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
#        'LCB', 'CB', 'RCB', 'RB', 'ID'],
#       dtype='object')
# 176580
# (1, 39)
# Index(['Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Release Clause',
#        'Position', 'Jersey Number', 'Joined', 'Contract Valid Until', 'LS',
#        'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM',
#        'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
#        'LCB', 'CB', 'RCB', 'RB', 'ID'],
#       dtype='object')
# 155862
# (1, 39)
# Index(['Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Release Clause',
#        'Position', 'Jersey Number', 'Joined', 'Contract Valid Until', 'LS',
#        'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM',
#        'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
#        'LCB', 'CB', 'RCB', 'RB', 'ID'],
#       dtype='object')
# 200389
# (1, 39)
# Index(['Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Release Clause',
#        'Position', 'Jersey Number', 'Joined', 'Contract Valid Until', 'LS',
#        'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM',
#        'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
#        'LCB', 'CB', 'RCB', 'RB', 'ID'],
#       dtype='object')
# 192119
# (1, 39)
# Index(['Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Release Clause',
#        'Position', 'Jersey Number', 'Joined', 'Contract Valid Until', 'LS',
#        'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM',
#        'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
#        'LCB', 'CB', 'RCB', 'RB', 'ID'],
#       dtype='object')
# 188545
# (1, 39)
# Index(['Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Release Clause',
#        'Position', 'Jersey Number', 'Joined', 'Contract Valid Until', 'LS',
#        'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM',
#        'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
#        'LCB', 'CB', 'RCB', 'RB', 'ID'],
#       dtype='object')
# 182521
# (1, 39)
# Index(['Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Release Clause',
#        'Position', 'Jersey Number', 'Joined', 'Contract Valid Until', 'LS',
#        'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM',
#        'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
#        'LCB', 'CB', 'RCB', 'RB', 'ID'],
#       dtype='object')
# 182493
# (1, 39)
# Index(['Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Release Clause',
#        'Position', 'Jersey Number', 'Joined', 'Contract Valid Until', 'LS',
#        'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM',
#        'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
#        'LCB', 'CB', 'RCB', 'RB', 'ID'],
#       dtype='object')
# 167495
# (1, 39)
# Index(['Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Release Clause',
#        'Position', 'Jersey Number', 'Joined', 'Contract Valid Until', 'LS',
#        'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM',
#        'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
#        'LCB', 'CB', 'RCB', 'RB', 'ID'],
#       dtype='object')
# 215914
# (1, 39)
# Index(['Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Release Clause',
#        'Position', 'Jersey Number', 'Joined', 'Contract Valid Until', 'LS',
#        'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM',
#        'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
#        'LCB', 'CB', 'RCB', 'RB', 'ID'],
#       dtype='object')
# 211110
# (1, 39)
# Index(['Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Release Clause',
#        'Position', 'Jersey Number', 'Joined', 'Contract Valid Until', 'LS',
#        'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM',
#        'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
#        'LCB', 'CB', 'RCB', 'RB', 'ID'],
#       dtype='object')
# 202126
# (1, 39)
# Index(['Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Release Clause',
#        'Position', 'Jersey Number', 'Joined', 'Contract Valid Until', 'LS',
#        'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM',
#        'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
#        'LCB', 'CB', 'RCB', 'RB', 'ID'],
#       dtype='object')
# 197781
# (1, 39)
# Index(['Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Release Clause',
#        'Position', 'Jersey Number', 'Joined', 'Contract Valid Until', 'LS',
#        'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM',
#        'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
#        'LCB', 'CB', 'RCB', 'RB', 'ID'],
#       dtype='object')
# 194765
# (1, 39)
# Index(['Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Release Clause',
#        'Position', 'Jersey Number', 'Joined', 'Contract Valid Until', 'LS',
#        'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM',
#        'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
#        'LCB', 'CB', 'RCB', 'RB', 'ID'],
#       dtype='object')
# 192448
# (1, 39)
# Index(['Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Release Clause',
#        'Position', 'Jersey Number', 'Joined', 'Contract Valid Until', 'LS',
#        'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM',
#        'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
#        'LCB', 'CB', 'RCB', 'RB', 'ID'],
#       dtype='object')
# 179813
# (1, 39)
# Index(['Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Release Clause',
#        'Position', 'Jersey Number', 'Joined', 'Contract Valid Until', 'LS',
#        'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM',
#        'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
#        'LCB', 'CB', 'RCB', 'RB', 'ID'],
#       dtype='object')
# 178603
# (1, 39)
# Index(['Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Release Clause',
#        'Position', 'Jersey Number', 'Joined', 'Contract Valid Until', 'LS',
#        'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM',
#        'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
#        'LCB', 'CB', 'RCB', 'RB', 'ID'],
#       dtype='object')
# 168542
# (1, 39)
# Index(['Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Release Clause',
#        'Position', 'Jersey Number', 'Joined', 'Contract Valid Until', 'LS',
#        'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM',
#        'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
#        'LCB', 'CB', 'RCB', 'RB', 'ID'],
#       dtype='object')
# 153079
# (1, 39)
# Index(['Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Release Clause',
#        'Position', 'Jersey Number', 'Joined', 'Contract Valid Until', 'LS',
#        'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM',
#        'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
#        'LCB', 'CB', 'RCB', 'RB', 'ID'],
#       dtype='object')
# 138956
# (1, 39)
# Index(['Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Release Clause',
#        'Position', 'Jersey Number', 'Joined', 'Contract Valid Until', 'LS',
#        'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM',
#        'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
#        'LCB', 'CB', 'RCB', 'RB', 'ID'],
#       dtype='object')
# 209331
# (1, 39)
# Index(['Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Release Clause',
#        'Position', 'Jersey Number', 'Joined', 'Contract Valid Until', 'LS',
#        'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM',
#        'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
#        'LCB', 'CB', 'RCB', 'RB', 'ID'],
#       dtype='object')
# 200145
# (1, 39)
# Index(['Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Release Clause',
#        'Position', 'Jersey Number', 'Joined', 'Contract Valid Until', 'LS',
#        'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM',
#        'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
#        'LCB', 'CB', 'RCB', 'RB', 'ID'],
#       dtype='object')
# 198710
# (1, 38)
# Index(['Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Position',
#        'Jersey Number', 'Loaned From', 'Contract Valid Until', 'LS', 'ST',
#        'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM', 'LCM',
#        'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB',
#        'RCB', 'RB', 'ID'],
#       dtype='object')
# 198219
# (1, 39)
# Index(['Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Release Clause',
#        'Position', 'Jersey Number', 'Joined', 'Contract Valid Until', 'LS',
#        'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM',
#        'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
#        'LCB', 'CB', 'RCB', 'RB', 'ID'],
#       dtype='object')
# 195864
# (1, 39)
# Index(['Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Release Clause',
#        'Position', 'Jersey Number', 'Joined', 'Contract Valid Until', 'LS',
#        'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM',
#        'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
#        'LCB', 'CB', 'RCB', 'RB', 'ID'],
#       dtype='object')
# 190460
# (1, 39)
# Index(['Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Release Clause',
#        'Position', 'Jersey Number', 'Joined', 'Contract Valid Until', 'LS',
#        'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM',
#        'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
#        'LCB', 'CB', 'RCB', 'RB', 'ID'],
#       dtype='object')
# 189511
# (1, 39)
# Index(['Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Release Clause',
#        'Position', 'Jersey Number', 'Joined', 'Contract Valid Until', 'LS',
#        'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM',
#        'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
#        'LCB', 'CB', 'RCB', 'RB', 'ID'],
#       dtype='object')
# 189242
# (1, 39)
# Index(['Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Release Clause',
#        'Position', 'Jersey Number', 'Joined', 'Contract Valid Until', 'LS',
#        'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM',
#        'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
#        'LCB', 'CB', 'RCB', 'RB', 'ID'],
#       dtype='object')
# 188567
# (1, 39)
# Index(['Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Release Clause',
#        'Position', 'Jersey Number', 'Joined', 'Contract Valid Until', 'LS',
#        'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM',
#        'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
#        'LCB', 'CB', 'RCB', 'RB', 'ID'],
#       dtype='object')
# 176676
# (1, 39)
# Index(['Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Release Clause',
#        'Position', 'Jersey Number', 'Joined', 'Contract Valid Until', 'LS',
#        'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM',
#        'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
#        'LCB', 'CB', 'RCB', 'RB', 'ID'],
#       dtype='object')
# 173731
# (1, 39)
# Index(['Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Release Clause',
#        'Position', 'Jersey Number', 'Joined', 'Contract Valid Until', 'LS',
#        'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM', 'CAM', 'RAM', 'LM',
#        'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM', 'CDM', 'RDM', 'RWB', 'LB',
#        'LCB', 'CB', 'RCB', 'RB', 'ID'],
#       dtype='object')
# 167948
# (1, 39)
# Index(['Preferred Foot', 'International Reputation', 'Weak Foot',
#        'Skill Moves', 'Work Rate', 'Body Type', 'Real Face', 'Release Clause',
#        'Position', 'Jersey Number', 'Joined', 'Contract Valid Until', 'LB',
#        'LCB', 'LCM', 'LDM', 'LF', 'LM', 'LS', 'LW', 'LWB', 'Loaned From',
#        'Position', 'Preferred Foot', 'RAM', 'RB', 'RCB', 'RCM', 'RDM', 'RF',
#        'RM', 'RS', 'RW', 'RWB', 'Real Face', 'Release Clause', 'ST',
#        'Skill Moves', 'ID'],
#       dtype='object')
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-4198ebff2f6f> in <module>()
#      41     print(attr_data.shape)
#      42     print(attr_data.columns)
# ---> 43     master_data = master_data.append([attr_data])
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    6209         return concat(to_concat, ignore_index=ignore_index,
#    6210                       verify_integrity=verify_integrity,
# -> 6211                       sort=sort)
#    6212
#    6213     def join(self, other, on=None, how='left', lsuffix='', rsuffix='',
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     224                        verify_integrity=verify_integrity,
#     225                        copy=copy, sort=sort)
# --> 226     return op.get_result()
#     227
#     228
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/reshape/concat.py in get_result(self)
#     421             new_data = concatenate_block_managers(
#     422                 mgrs_indexers, self.new_axes, concat_axis=self.axis,
# --> 423                 copy=self.copy)
#     424             if not self.copy:
#     425                 new_data._consolidate_inplace()
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in concatenate_block_managers(mgrs_indexers, axes, concat_axis, copy)
#    5404     blocks = []
#    5405
# -> 5406     for placement, join_units in concat_plan:
#    5407
#    5408         if len(join_units) == 1 and not join_units[0].indexers:
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in combine_concat_plans(plans, concat_axis)
#    5697         while num_ended[0] != len(next_items):
#    5698             if num_ended[0] > 0:
# -> 5699                 raise ValueError("Plan shapes are not aligned")
#    5700
#    5701             placements, units = zip(*next_items)
#
# ValueError: Plan shapes are not aligned

# %%
        skill_names = []
        skill_map = {'ID' : str(167948)}
        url = player_data_url + str(167948)
        source_code = requests.get(url)
        plain_text = source_code.text
        soup = BeautifulSoup(plain_text)
        categories = soup.find('div', {'class': 'teams'}).findAll('div', {'class': 'column col-4'})[0:3]
        for category in categories:
            skills = category.findAll('li')
            for skill in skills:
                if(skill.find('label') != None):
                    a = skill.text
                    n = skill.find('label').text
                    value = a.replace(n, '').strip()
                    skill_names.append(n)
                    skill_map[str(n)] = value
        
        if(soup.find('aside').find('div', {'class': 'card mb-2'}).find('div', {'class': 'card-body'})):
            card_rows = soup.find('aside').find('div', {'class': 'card mb-2'}).find('div', {'class': 'card-body'}).findAll('div', {'class': 'columns'})
            for row in card_rows:
                attributes = row.findAll('div', {'class': re.compile('column col-sm-2 text-center')})
                for attribute in attributes:
                    if(attribute.find('div')):
                        text = attribute.text
                        name = ''.join(re.findall('[a-zA-Z]', text))
                        value = text.replace(name, '').strip()
                        skill_names.append(name)
                        skill_map[str(name)] = value
        else:
            for name in master_data.columns[12:38]:
                skill_names.append(name)
                skill_map[str(name)] = None
        attr_data = DataFrame(columns=skill_names)
        for key in skill_map.keys():
            attr_data.loc[r,key] = skill_map[key]
        r = r + 1
        
        print(skill_map)
# Out:
# {'ID': '167948', 'Preferred Foot': None, 'International Reputation': '4', 'Weak Foot': '1', 'Skill Moves': None, 'Work Rate': 'Medium/ Medium', 'Body Type': 'Lean', 'Real Face': None, 'Release Clause': None, 'Position': None, 'Jersey Number': '1', 'Joined': 'Aug 1, 2012', 'Contract Valid Until': '2022', 'LB': None, 'LCB': None, 'LCM': None, 'LDM': None, 'LF': None, 'LM': None, 'LS': None, 'LW': None, 'LWB': None, 'Loaned From': None, 'RAM': None, 'RB': None, 'RCB': None, 'RCM': None, 'RDM': None, 'RF': None, 'RM': None, 'RS': None, 'RW': None, 'RWB': None, 'ST': None}

# %%
full_data = pd.merge(data, master_data, left_index=True, right_index=True)

# %%
full_data.drop('Unnamed: 0', 1,  inplace=True)

# %%
full_data.drop('ID_x', 1,  inplace=True)

# %%
f = full_data.rename(index=str, columns={"ID_y": "ID"})

# %%
full_data.to_csv('Complete/Dataset.csv', encoding='utf-8')

# %%
full_data['ID_y'][:5]

# %%
f['ID'][:5]

# %%
f.to_csv('Complete/Dataset.csv', encoding='utf-8')
